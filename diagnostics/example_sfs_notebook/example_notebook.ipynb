# %% [markdown]
# #  MDTF Example Diagnostic POD Notebook for Multiple Cases / Experiments

# %% [markdown]
# ================================================================================ <br>
# This notebook does a simple diagnostic calculation to illustrate how to adapt code
# for use in the MDTF-diagnostics framework. The main change is to set input/output
# paths, variable names etc..., from shell environment variables the framework
# provides, instead of hard-coding them.
#
# Below, this notebook consists of 3 parts: (1) a header template POD
# developers must include in their POD's main driver script, (2) actual code, and
# (3) extensive in-line comments.<br>
# ================================================================================
#
# This file is part of the Example Diagnostic POD of the MDTF code package (see mdtf/MDTF-diagnostics/LICENSE.txt)
#
# ## Example Diagnostic POD
#
#    Last update: 8/23/2024
#
#    This is an example POD that you can use as a template for your diagnostics.
#    If this were a real POD, you'd place a one-paragraph synopsis of your
#    diagnostic here (like an abstract).
#
#    ### Version & Contact info
#
#    Here you should describe who contributed to the diagnostic, and who should be
#    contacted for further information:
#
#    - Version/revision information: version 1 (5/06/2020)
#    - PI (name, affiliation, email)
#    - Developer/point of contact (name, affiliation, email)
#    - Other contributors
#
#    ### Open source copyright agreement
#
#    The MDTF framework is distributed under the LGPLv3 license (see LICENSE.txt).
#    Unless you've distributed your script elsewhere, you don't need to change this.
#
#    ### Functionality
#
#    In this section you should summarize the stages of the calculations your
#    diagnostic performs, and how they translate to the individual source code files
#    provided in your submission. This help maintainers to fix bugs or
#    people with questions about how your code works know where to look.
#
#    ### Required programming language and libraries
#
#    In this section you should summarize the programming languages and third-party
#    libraries used by your diagnostic. You also provide this information in the
#    ``settings.jsonc`` file, but here you can give helpful comments to human
#    maintainers (eg, "We need at least version 1.5 of this library because we call
#    this function.")
#
#    * Python >= 3.12
#    * xarray
#    * matplotlib
#    * intake
#    * yaml
#    * sys
#    * os
#    * numpy
#
#    ### Required model output variables
#
#    In this section you should describe each variable in the input data your
#    diagnostic uses. You also need to provide this in the ``settings.jsonc`` file,
#    but here you should go into detail on the assumptions your diagnostic makes
#    about the structure of the data.
#
#    * tas - Surface (2-m) air temperature (CF: air_temperature)
#
#    ### References
#
#    Here you should cite the journal articles providing the scientific basis for
#    your diagnostic.
#
#       Maloney, E. D, and Co-authors, 2019: Process-oriented evaluation of climate
#          and wether forcasting models. BAMS, 100(9), 1665-1686,
#          doi:10.1175/BAMS-D-18-0042.1.

# %%
# Import modules used in the POD
import os
import matplotlib

matplotlib.use('Agg')  # non-X windows backend

import matplotlib.pyplot as plt
import numpy as np
import intake
import sys
import yaml

# %% [markdown]
# # Part 1: Read in the model data

# %%
os.environ["WORK_DIR"] = "/data/mgehne/mdtf/wkdir/example_sfs_notebook/"
os.environ["case_env_file"] = "/home/mgehne/mdtf/MDTF-diagnostics/diagnostics/example_sfs_notebook/case_info.yml"
os.environ['CATALOG_FILE'] = "/home/mgehne/mdtf/MDTF-diagnostics/diagnostics/example_sfs_notebook/sfs_catalog_test.json"

# %%
# Receive a dictionary of case information from the framework
print("reading case_info")
case_env_file = os.environ["case_env_file"]
assert os.path.isfile(case_env_file), f"case environment file not found"
with open(case_env_file, 'r') as stream:
    try:
        case_info = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

cat_def_file = case_info['CATALOG_FILE']
case_list = case_info['CASE_LIST']
# all cases share variable names and dimension coords in this example, so just get first result for each
tas_vars = [case['tas_var'] for case in case_list.values()]
time_coord = [case['time_coord'] for case in case_list.values()][0]
lat_coord = [case['lat_coord'] for case in case_list.values()][0]
lon_coord = [case['lon_coord'] for case in case_list.values()][0]
startdates  = [case['startdate'] for case in case_list.values()]
print(startdates)
# Out:
# reading case_info
# ['1994-11-01', '1995-11-01', '1995-11-01']

# %% [markdown]
# ## What is in the data catalog?

# %%
# open the csv file using information provided by the catalog definition file
cat = intake.open_esm_datastore(cat_def_file)
cat
# Out:
# /home/mgehne/.conda/envs/_MDTF_python3_base_test_zarr/lib/python3.12/site-packages/intake_esm/__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# <p><strong>sfs_test catalog with 3 dataset(s) from 3 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>standard_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat.df

# %% [markdown]
# ## Searching for TAS DAILY output for my POD

# %%
tas_subset = cat.search(variable_id='tsfc', frequency="mon")
tas_subset
# Out:
# <p><strong>sfs_test catalog with 3 dataset(s) from 3 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>standard_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
tas_subset.df

# %%
# convert tas_subset catalog to an xarray dataset dict
tas_dict = tas_subset.to_dataset_dict(
    progressbar=False,
    aggregate=False,
    xarray_open_kwargs={"decode_times": True, "use_cftime": True}
)

# renaming keys in tas_dict to that found in case_list
tas_keys = list(tas_dict) 
case_keys = list(case_list)
print(tas_keys)
print(case_keys)
for i in range(len(tas_keys)):
    print(case_keys[i])
    print(tas_keys[i])
    tas_dict[case_keys[i]] = tas_dict.pop(tas_keys[i])
# Out:
# ['SFS.SFS_baseline_cpc.atmos.tsfc.surface_temperature.Surface Temperature.mon.mm.1994-11-01 0:00:00.1995-10-01 0:00:00.1994-11-01 0:00:00-1995-10-01 0:00:00.s3://noaa-oar-sfsdev-pds/experiments/phase_1/cpc_ics/atm_monthly.zarr', 'SFS.SFS_baseline_cpc.atmos.tsfc.surface_temperature.Surface Temperature.mon.mm.1995-11-01 0:00:00.1996-10-01 0:00:00.1995-11-01 0:00:00-1996-10-01 0:00:00.s3://noaa-oar-sfsdev-pds/experiments/phase_1/cpc_ics/atm_monthly.zarr', 'SFS.SFS_betaV0.1.atmos.tsfc.surface_temperature.Surface Temperature.mon.mm.1994-11-01 0:00:00.1995-10-01 0:00:00.1994-11-01 0:00:00-1995-10-01 0:00:00.s3://noaa-oar-sfsdev-pds/experiments/phase_1/c96_beta.0.1/atm_monthly.zarr']
# ['SFS_baseline_cpc_199411', 'SFS_baseline_cpc_199511', 'SFS_betaV0.1_199511']
# SFS_baseline_cpc_199411
# SFS.SFS_baseline_cpc.atmos.tsfc.surface_temperature.Surface Temperature.mon.mm.1994-11-01 0:00:00.1995-10-01 0:00:00.1994-11-01 0:00:00-1995-10-01 0:00:00.s3://noaa-oar-sfsdev-pds/experiments/phase_1/cpc_ics/atm_monthly.zarr
# SFS_baseline_cpc_199511
# SFS.SFS_baseline_cpc.atmos.tsfc.surface_temperature.Surface Temperature.mon.mm.1995-11-01 0:00:00.1996-10-01 0:00:00.1995-11-01 0:00:00-1996-10-01 0:00:00.s3://noaa-oar-sfsdev-pds/experiments/phase_1/cpc_ics/atm_monthly.zarr
# SFS_betaV0.1_199511
# SFS.SFS_betaV0.1.atmos.tsfc.surface_temperature.Surface Temperature.mon.mm.1994-11-01 0:00:00.1995-10-01 0:00:00.1994-11-01 0:00:00-1995-10-01 0:00:00.s3://noaa-oar-sfsdev-pds/experiments/phase_1/c96_beta.0.1/atm_monthly.zarr

# %%
print(tas_dict)

# %% [markdown]
# ## Let us do some calculations

# %%
# Part 2: Do some calculations (time and zonal means)
# ---------------------------------------------------

tas_arrays = {}

# Loop over cases
for k, v in tas_dict.items():
    # load the tas data for case k
    print("case:",k)
    var = case_list[k]['tas_var']
    initdate = case_list[k]['startdate']    
    arr = tas_dict[k][var].sel(init=initdate).squeeze()

    # take the time mean
    arr = arr.mean(dim=(tas_dict[k][time_coord].name,'member'))

    # convert to anomalies
    # arr = arr - arr.mean()

    # take the zonal mean
    arr = arr.mean(dim=tas_dict[k][lon_coord].name)

    tas_arrays[k] = arr
# Out:
# case: SFS_baseline_cpc_199411
# case: SFS_baseline_cpc_199511
# case: SFS_betaV0.1_199511

# %%
print(tas_arrays)
# Out:
# {'SFS_baseline_cpc_199411': <xarray.DataArray 'tmpsfc' (lat: 181)> Size: 724B
# dask.array<mean_agg-aggregate, shape=(181,), dtype=float32, chunksize=(181,), chunktype=numpy.ndarray>
# Coordinates:
#     atmosphereSingleLayer  float64 8B 0.0
#     depthBelowLandLayer    float64 8B 0.0
#     heightAboveGround      float64 8B 2.0
#     init                   object 8B 1994-11-01 00:00:00
#   * lat                    (lat) float64 1kB 90.0 89.0 88.0 ... -89.0 -90.0
#     meanSea                float64 8B 0.0
#     nominalTop             float64 8B 0.0
#     surface                float64 8B 0.0, 'SFS_baseline_cpc_199511': <xarray.DataArray 'tmpsfc' (init: 0, lat: 181)> Size: 0B
# dask.array<mean_agg-aggregate, shape=(0, 181), dtype=float32, chunksize=(0, 181), chunktype=numpy.ndarray>
# Coordinates:
#     atmosphereSingleLayer  float64 8B 0.0
#     depthBelowLandLayer    float64 8B 0.0
#     heightAboveGround      float64 8B 2.0
#   * init                   (init) object 0B
#   * lat                    (lat) float64 1kB 90.0 89.0 88.0 ... -89.0 -90.0
#     meanSea                float64 8B 0.0
#     nominalTop             float64 8B 0.0
#     surface                float64 8B 0.0, 'SFS_betaV0.1_199511': <xarray.DataArray 'tsfc' (lat: 181)> Size: 1kB
# dask.array<mean_agg-aggregate, shape=(181,), dtype=float64, chunksize=(181,), chunktype=numpy.ndarray>
# Coordinates:
#     init     object 8B 1995-11-01 00:00:00
#   * lat      (lat) int64 1kB 90 89 88 87 86 85 84 ... -85 -86 -87 -88 -89 -90}

# %% [markdown]
# ### We are comparing the above cases

# %%
# Part 3: Make a plot that contains results from each case
# --------------------------------------------------------
print("Let's plot!")
print("--------------------------------------")

# set up the figure
fig = plt.figure(figsize=(12, 4))
ax = plt.subplot(1, 1, 1)

# loop over cases
for k, v in tas_arrays.items():
    print("case:",k)
    v.plot(ax=ax, label=k)

# add legend
plt.legend()

# add title
plt.title("Zonal Mean Surface Air Temperature Anomaly")
plt.show()
# Out:
# Let's plot!
# --------------------------------------
# case: SFS_baseline_cpc_199411
# <xarray.DataArray 'tmpsfc' (lat: 181)> Size: 724B
# dask.array<mean_agg-aggregate, shape=(181,), dtype=float32, chunksize=(181,), chunktype=numpy.ndarray>
# Coordinates:
#     atmosphereSingleLayer  float64 8B ...
#     depthBelowLandLayer    float64 8B ...
#     heightAboveGround      float64 8B ...
#     init                   object 8B 1994-11-01 00:00:00
#   * lat                    (lat) float64 1kB 90.0 89.0 88.0 ... -89.0 -90.0
#     meanSea                float64 8B ...
#     nominalTop             float64 8B ...
#     surface                float64 8B ...
# case: SFS_baseline_cpc_199511
# <xarray.DataArray 'tmpsfc' (lat: 181)> Size: 724B
# dask.array<mean_agg-aggregate, shape=(181,), dtype=float32, chunksize=(181,), chunktype=numpy.ndarray>
# Coordinates:
#     atmosphereSingleLayer  float64 8B ...
#     depthBelowLandLayer    float64 8B ...
#     heightAboveGround      float64 8B ...
#     init                   object 8B 1995-11-01 00:00:00
#   * lat                    (lat) float64 1kB 90.0 89.0 88.0 ... -89.0 -90.0
#     meanSea                float64 8B ...
#     nominalTop             float64 8B ...
#     surface                float64 8B ...
# case: SFS_betaV0.1_199511
# <xarray.DataArray 'tsfc' (lat: 181)> Size: 1kB
# dask.array<mean_agg-aggregate, shape=(181,), dtype=float64, chunksize=(181,), chunktype=numpy.ndarray>
# Coordinates:
#     init     object 8B 1995-11-01 00:00:00
#   * lat      (lat) int64 1kB 90 89 88 87 86 85 84 ... -85 -86 -87 -88 -89 -90

# %%
# %matplotlib Agg
#inline
# save the plot in the right location
work_dir = os.environ["WORK_DIR"]
assert os.path.isdir(f"{work_dir}/model/PS"), f'Assertion error: {work_dir}/model/PS not found'

plt.savefig(f"{work_dir}/model/PS/example_sfs_notebook_plot.eps", bbox_inches="tight")
plt.show()

# %%
# Part 4: running an external script
# the use of external python scripts can help prevent bloat in the notebook
# here, we show how this can be done
sys.path.append(os.environ["POD_HOME"])
import script
script.HelloWorld()

# %%
# Part 5: Close the catalog files and
# release variable dict reference for garbage collection
# ------------------------------------------------------
cat.close()
tas_dict = None

# Part 6: Confirm POD executed successfully
# ----------------------------------------
print("Last log message by example_multicase POD: finished successfully!")
